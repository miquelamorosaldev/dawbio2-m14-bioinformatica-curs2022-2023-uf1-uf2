# %% [markdown]
# ## DIST. NORMAL SEABORN
#
# https://www.statology.org/seaborn-normal-distribution/

# %%
import numpy as np
import seaborn as sns

#make this example reproducible
np.random.seed(0)

#create data
mu = 80
sigma = 15
x = np.random.normal(mu,sigma,size=10000)

#create normal distribution histogram and distribution curve
sns.displot(x, kde=True)

# %%
sns.heatmap(x)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [5], line 1
# ----> 1 sns.heatmap(x)
#
# File ~/anaconda3/envs/bio/lib/python3.10/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~/anaconda3/envs/bio/lib/python3.10/site-packages/seaborn/matrix.py:540, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     362 """Plot rectangular data as a color-encoded matrix.
#     363
#     364 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     537     ...     ax = sns.heatmap(corr, mask=mask, vmax=.3, square=True)
#     538 """
#     539 # Initialize the plotter object
# --> 540 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     541                       annot_kws, cbar, cbar_kws, xticklabels,
#     542                       yticklabels, mask)
#     544 # Add the pcolormesh kwargs here
#     545 kwargs["linewidths"] = linewidths
#
# File ~/anaconda3/envs/bio/lib/python3.10/site-packages/seaborn/matrix.py:111, in _HeatMapper.__init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     108 # Validate the mask and convet to DataFrame
#     109 mask = _matrix_mask(data, mask)
# --> 111 plot_data = np.ma.masked_where(np.asarray(mask), plot_data)
#     113 # Get good names for the rows and columns
#     114 xtickevery = 1
#
# File ~/anaconda3/envs/bio/lib/python3.10/site-packages/numpy/ma/core.py:1926, in masked_where(condition, a, copy)
#    1924 (cshape, ashape) = (cond.shape, a.shape)
#    1925 if cshape and cshape != ashape:
# -> 1926     raise IndexError("Inconsistent shape between the condition and the input"
#    1927                      " (got %s and %s)" % (cshape, ashape))
#    1928 if hasattr(a, '_mask'):
#    1929     cond = mask_or(cond, a._mask)
#
# IndexError: Inconsistent shape between the condition and the input (got (10000, 1) and (10000,))
